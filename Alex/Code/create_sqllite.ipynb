# %%
# data science
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# API
import requests
import json

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, text, inspect, func
import plotly.express as px

# %%
#Reading csv file
raw_data = pd.read_csv('Supercharge Locations.csv',encoding='unicode_escape')
raw_data.head(50)
# Out:
#                                          Supercharger  \
# 0                                        Buellton, CA
# 1                                         Corning, CA
# 2                                         Barstow, CA
# 3                                          Tifton, GA
# 4                                       Roseville, CA
# 5                                          Oxnard, CA
# 6                Daytona Beach - Gateway North Dr, FL
# 7                                  Port St. Lucie, FL
# 8                                Dallas - Park Ln, TX
# 9                                Dangjin, South Korea
# 10                                 Björkliden, Sweden
# 11                                      El Centro, CA
# 12                                       Rosemont, IL
# 13                                          Indio, CA
# 14                                       Savannah, GA
# 15                                       Holbrook, AZ
# 16                                    Mooresville, NC
# 17             Shenzhen - Longhua Tesla Center, China
# 18                                        Buckeye, AZ
# 19                                     Atascadero, CA
# 20                                      Gila Bend, AZ
# 21                                           Yuma, AZ
# 22                         Greenwich - Northbound, CT
# 23                           Milford - Northbound, CT
# 24                                    Port Orange, FL
# 25  Guangzhou - Panyu Yingbin Road Tesla Center, C...
# 26             Wenling - Taizhou Tesla Service, China
# 27                                    Worthington, MN
# 28                                     Burlington, NC
# 29                    Quanzhou - Donghai Vanke, China
# 30                                      Spearfish, SD
# 31                                         Santee, SC
# 32                                      Mishawaka, IN
# 33                                         Angola, IN
# 34                                       Richmond, CA
# 35                                     Farmington, NM
# 36                                       Goodland, KS
# 37                                       Somerset, PA
# 38                                       Ossining, NY
# 39                                     San Marcos, TX
# 40                                       Columbus, TX
# 41                                       Mitchell, SD
# 42                   San Luis Obispo - Higuera St, CA
# 43                                 East Greenwich, RI
# 44                                         Maumee, OH
# 45                               Pleasant Prairie, WI
# 46                             Cranberry Township, PA
# 47                                     Rapid City, SD
# 48                                      Lumberton, NC
# 49                                    Yokohama, Japan
#
#                                        Street Address                City  \
# 0                                     555 McMurray Rd            Buellton
# 1                                          950 Hwy 99             Corning
# 2                                     2812 Lenwood Rd             Barstow
# 3                                        1310 U.S. 82              Tifton
# 4                                  1151 Galleria Blvd           Roseville
# 5                                   2751 Park View Ct              Oxnard
# 6                                   2330 Gateway N Dr       Daytona Beach
# 7                                1701 NW Peacock Blvd      Port St. Lucie
# 8                                        8080 Park Ln              Dallas
# 9   63, Songak-ro, Songak-eup, Dangjin-si, Chungch...             Dangjin
# 10                                 Björklidenvägen 70          Björkliden
# 11                                  3451 S Dogwood Rd           El Centro
# 12                           5220 Fashion Outlets Way            Rosemont
# 13                                   42100 Jackson St               Indio
# 14                                    400 Airways Ave            Savannah
# 15                                   2096 Navajo Blvd            Holbrook
# 16                               125 Center Square Dr         Mooresville
# 17  Longhua Auto City, No.1 Minkang Rd, Longhua Di...            Shenzhen
# 18                                    416 S Watson Rd             Buckeye
# 19                                6950 El Camino Real          Atascadero
# 20                                      826 W Pima St           Gila Bend
# 21                                  310 N Madison Ave                Yuma
# 22                                  3000 Merritt Pkwy           Greenwich
# 23                                    1 CT Turnpike N             Milford
# 24                             5302 S Williamson Blvd         Port Orange
# 25  Room 101-110, Building 1, Chuangqi I.PARK, No....           Guangzhou
# 26  China Zhejiang Trading Center, Maoyang Village...             Wenling
# 27                                     1290 Ryan's Rd         Worthington
# 28                                      1080 Piper Ln          Burlington
# 29  ITC Vanke Center, 188 Quannan Road, Bincheng C...            Quanzhou
# 30                                  3275 Old Belle Rd           Spearfish
# 31                                  114 Bradford Blvd              Santee
# 32                                      6501 Grape Rd           Mishawaka
# 33                               3855 Indiana Rte 127              Angola
# 34                                    2157 Meeker Ave            Richmond
# 35                               4200 Sierra Vista Dr          Farmington
# 36                                 2631 Enterprise Rd            Goodland
# 37                                  1030 N Center Ave            Somerset
# 38                             214 South Highland Ave            Ossining
# 39                                 3939 Interstate 35          San Marcos
# 40                                      2535 Texas 71            Columbus
# 41                                   1305 W Havens St            Mitchell
# 42                                  3897 S Higuera St     San Luis Obispo
# 43                                   1000 Division St      East Greenwich
# 44                                     1391 Conant St              Maumee
# 45                                    11211 120th Ave    Pleasant Prairie
# 46                                    1308 Freedom Rd  Cranberry Township
# 47                                   2200 N Maple Ave          Rapid City
# 48                               5093 Fayetteville Rd           Lumberton
# 49                     Kanagawa, Totsuka Kamiyabe-cho            Yokohama
#
#              State     Zip      Country  Stalls     kW  \
# 0               CA   93427          USA      10  150.0
# 1               CA   96021          USA       6  150.0
# 2               CA   92311          USA      16  150.0
# 3               GA   31794          USA       8  150.0
# 4               CA   95678          USA       7  150.0
# 5               CA   93036          USA      20  150.0
# 6               FL   32117          USA      12  250.0
# 7               FL   34986          USA      16  150.0
# 8               TX   75231          USA      16  250.0
# 9   Chungcheongnam     NaN  South Korea       4  120.0
# 10        Lappland  981 93       Sweden       3  250.0
# 11              CA   92243          USA      12  150.0
# 12              IL   60018          USA      10   72.0
# 13              CA   92203          USA      46  250.0
# 14              GA   31408          USA       8  125.0
# 15              AZ   86025          USA      12  250.0
# 16              NC   28117          USA      12  250.0
# 17       Guangdong  518131        China      10  120.0
# 18              AZ   85326          USA      12  250.0
# 19              CA   93422          USA       8  125.0
# 20              AZ   85337          USA      16  250.0
# 21              AZ   85364          USA      12  250.0
# 22              CT    6830          USA       4  150.0
# 23              CT    6460          USA       2  120.0
# 24              FL   32128          USA       6  150.0
# 25       Guangdong     NaN        China       6  250.0
# 26        Zhejiang     NaN        China       3  250.0
# 27              MN   56187          USA       6  120.0
# 28              NC   27215          USA       8  120.0
# 29          Fujian     NaN        China       3  250.0
# 30              SD   57783          USA       6  150.0
# 31              SC   29142          USA       8  150.0
# 32              IN   46545          USA       6  120.0
# 33              IN   46703          USA       6  120.0
# 34              CA   94804          USA      12  150.0
# 35              NM   87402          USA       4  120.0
# 36              KS   67735          USA       6  150.0
# 37              PA   15501          USA       6  150.0
# 38              NY   10510          USA      12  150.0
# 39              TX   78666          USA      12  150.0
# 40              TX   78934          USA       6  120.0
# 41              SD   57301          USA       6  120.0
# 42              CA   93401          USA      20  250.0
# 43              RI    2818          USA       8  150.0
# 44              OH   43537          USA       8  150.0
# 45              WI   53158          USA       8  120.0
# 46              PA   16066          USA       6  150.0
# 47              SD   57701          USA       4  120.0
# 48              NC   28358          USA       8  150.0
# 49             NaN   995-1        Japan       4  120.0
#
#                               GPS  Elev(m)   Open Date  Unnamed: 11
# 0           34.61456, -120.188387      114   7/13/2013          NaN
# 1          39.926454, -122.198393       87  10/18/2013          NaN
# 2          34.849129, -117.085446      725  11/19/2012          NaN
# 3            31.448847, -83.53221       92   7/10/2014          NaN
# 4          38.771208, -121.266149       66   4/29/2014          NaN
# 5          34.238654, -119.177398       24   9/24/2014          NaN
# 6            29.223265, -81.09972        7  11/19/2022          NaN
# 7           27.313023, -80.406688        8   7/25/2013          NaN
# 8           32.867639, -96.767245      179  11/17/2021          NaN
# 9         36.909503, 126.69407466       42  12/20/2019          NaN
# 10           68.407105, 18.676377      471  12/16/2021          NaN
# 11         32.760837, -115.532486       -8  12/28/2014          NaN
# 12          41.975091, -87.866501      194   11/6/2018          NaN
# 13         33.741484, -116.215019       -3   9/26/2014          NaN
# 14          32.135507, -81.212767        6   1/15/2014          NaN
# 15         34.922962, -110.145558     1596   1/15/2014          NaN
# 16             35.587472, -80.873      260  11/19/2021          NaN
# 17             22.6189, 114.05482       88   7/26/2014          NaN
# 18         33.443011, -112.556876      338   3/20/2014          NaN
# 19           35.48656, -120.66633      262    7/3/2013          NaN
# 20         32.943969, -112.733506      221   5/17/2014          NaN
# 21         32.726686, -114.619093       43    2/4/2014          NaN
# 22          41.041538, -73.671661       82   2/12/2014          NaN
# 23          41.245814, -73.008988       19  12/16/2012          NaN
# 24          29.108566, -81.034569        7   9/13/2013          NaN
# 25          23.024584, 113.339562        0   9/11/2022          NaN
# 26       28.39823725, 121.3092138        3   9/22/2022          NaN
# 27           43.63385, -95.595647      478  12/11/2013          NaN
# 28           36.07079, -79.511211      197  10/16/2013          NaN
# 29        24.8631032, 118.6796071        3   9/22/2022          NaN
# 30         44.520607, -103.890924     1077  10/30/2017          NaN
# 31          33.485858, -80.475763       39  12/27/2013          NaN
# 32              41.7174, -86.1887      234  12/11/2013          NaN
# 33          41.699048, -85.000326      329   12/9/2013          NaN
# 34         37.919969, -122.348976        4   9/16/2019          NaN
# 35         36.766371, -108.144047     1673   1/10/2014          NaN
# 36         39.326253, -101.725171     1129   6/13/2014          NaN
# 37          40.017383, -79.077117      641   1/10/2014          NaN
# 38          41.144011, -73.861472       21   6/14/2019          NaN
# 39          29.827692, -97.979677      202   8/17/2013          NaN
# 40          29.690062, -96.537725       57   10/7/2013          NaN
# 41  43.701129, -98.04449999999997      410  12/18/2013          NaN
# 42          35.247841, -120.67193       38  11/19/2021          NaN
# 43          41.660517, -71.497242       73    1/6/2014          NaN
# 44            41.57835, -83.66465      192   1/13/2014          NaN
# 45          42.518715, -87.950428      216   2/13/2014          NaN
# 46           40.683982, -80.10839      312    4/4/2014          NaN
# 47         44.105601, -103.212569     1006  11/25/2013          NaN
# 48          34.667629, -79.002343       40   1/17/2014          NaN
# 49        35.4260146, 139.5375485       43    9/9/2014          NaN

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5876 entries, 0 to 5875
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Supercharger    5876 non-null   object
#  1   Street Address  5876 non-null   object
#  2   City            5876 non-null   object
#  3   State           5754 non-null   object
#  4   Zip             3947 non-null   object
#  5   Country         5876 non-null   object
#  6   Stalls          5876 non-null   int64
#  7   kW              5870 non-null   float64
#  8   GPS             5876 non-null   object
#  9   Elev(m)         5876 non-null   int64
#  10  Open Date       5126 non-null   object
#  11  Unnamed: 11     0 non-null      float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 551.0+ KB

# %%
# splitting GPS Column to Latitude and Longitude
raw_data[['Latitude', 'Longitude']]=raw_data['GPS'].str.split(',', expand=True)
raw_data['Latitude']=raw_data['Latitude'].str.strip()
raw_data['Longitude']=raw_data['Longitude'].str.strip()
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5876 entries, 0 to 5875
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Supercharger    5876 non-null   object
#  1   Street Address  5876 non-null   object
#  2   City            5876 non-null   object
#  3   State           5754 non-null   object
#  4   Zip             3947 non-null   object
#  5   Country         5876 non-null   object
#  6   Stalls          5876 non-null   int64
#  7   kW              5870 non-null   float64
#  8   GPS             5876 non-null   object
#  9   Elev(m)         5876 non-null   int64
#  10  Open Date       5126 non-null   object
#  11  Unnamed: 11     0 non-null      float64
#  12  Latitude        5876 non-null   object
#  13  Longitude       5876 non-null   object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 642.8+ KB

# %%
#Deleting Extra Columns
raw_data=raw_data.drop(columns=['Zip', 'GPS', 'Unnamed: 11'], axis=1)
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5876 entries, 0 to 5875
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Supercharger    5876 non-null   object
#  1   Street Address  5876 non-null   object
#  2   City            5876 non-null   object
#  3   State           5754 non-null   object
#  4   Country         5876 non-null   object
#  5   Stalls          5876 non-null   int64
#  6   kW              5870 non-null   float64
#  7   Elev(m)         5876 non-null   int64
#  8   Open Date       5126 non-null   object
#  9   Latitude        5876 non-null   object
#  10  Longitude       5876 non-null   object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 505.1+ KB

# %%
#changing data types
raw_data['Open Date']= pd.to_datetime(raw_data['Open Date'])
raw_data[['Stalls' , 'Elev(m)']]=raw_data[['Stalls' , 'Elev(m)']].astype(int)
raw_data[['kW', 'Latitude','Longitude']]=raw_data[['kW','Latitude','Longitude']].astype(float)
raw_data.head(50)
# Out:
#                                          Supercharger  \
# 0                                        Buellton, CA
# 1                                         Corning, CA
# 2                                         Barstow, CA
# 3                                          Tifton, GA
# 4                                       Roseville, CA
# 5                                          Oxnard, CA
# 6                Daytona Beach - Gateway North Dr, FL
# 7                                  Port St. Lucie, FL
# 8                                Dallas - Park Ln, TX
# 9                                Dangjin, South Korea
# 10                                 Björkliden, Sweden
# 11                                      El Centro, CA
# 12                                       Rosemont, IL
# 13                                          Indio, CA
# 14                                       Savannah, GA
# 15                                       Holbrook, AZ
# 16                                    Mooresville, NC
# 17             Shenzhen - Longhua Tesla Center, China
# 18                                        Buckeye, AZ
# 19                                     Atascadero, CA
# 20                                      Gila Bend, AZ
# 21                                           Yuma, AZ
# 22                         Greenwich - Northbound, CT
# 23                           Milford - Northbound, CT
# 24                                    Port Orange, FL
# 25  Guangzhou - Panyu Yingbin Road Tesla Center, C...
# 26             Wenling - Taizhou Tesla Service, China
# 27                                    Worthington, MN
# 28                                     Burlington, NC
# 29                    Quanzhou - Donghai Vanke, China
# 30                                      Spearfish, SD
# 31                                         Santee, SC
# 32                                      Mishawaka, IN
# 33                                         Angola, IN
# 34                                       Richmond, CA
# 35                                     Farmington, NM
# 36                                       Goodland, KS
# 37                                       Somerset, PA
# 38                                       Ossining, NY
# 39                                     San Marcos, TX
# 40                                       Columbus, TX
# 41                                       Mitchell, SD
# 42                   San Luis Obispo - Higuera St, CA
# 43                                 East Greenwich, RI
# 44                                         Maumee, OH
# 45                               Pleasant Prairie, WI
# 46                             Cranberry Township, PA
# 47                                     Rapid City, SD
# 48                                      Lumberton, NC
# 49                                    Yokohama, Japan
#
#                                        Street Address                City  \
# 0                                     555 McMurray Rd            Buellton
# 1                                          950 Hwy 99             Corning
# 2                                     2812 Lenwood Rd             Barstow
# 3                                        1310 U.S. 82              Tifton
# 4                                  1151 Galleria Blvd           Roseville
# 5                                   2751 Park View Ct              Oxnard
# 6                                   2330 Gateway N Dr       Daytona Beach
# 7                                1701 NW Peacock Blvd      Port St. Lucie
# 8                                        8080 Park Ln              Dallas
# 9   63, Songak-ro, Songak-eup, Dangjin-si, Chungch...             Dangjin
# 10                                 Björklidenvägen 70          Björkliden
# 11                                  3451 S Dogwood Rd           El Centro
# 12                           5220 Fashion Outlets Way            Rosemont
# 13                                   42100 Jackson St               Indio
# 14                                    400 Airways Ave            Savannah
# 15                                   2096 Navajo Blvd            Holbrook
# 16                               125 Center Square Dr         Mooresville
# 17  Longhua Auto City, No.1 Minkang Rd, Longhua Di...            Shenzhen
# 18                                    416 S Watson Rd             Buckeye
# 19                                6950 El Camino Real          Atascadero
# 20                                      826 W Pima St           Gila Bend
# 21                                  310 N Madison Ave                Yuma
# 22                                  3000 Merritt Pkwy           Greenwich
# 23                                    1 CT Turnpike N             Milford
# 24                             5302 S Williamson Blvd         Port Orange
# 25  Room 101-110, Building 1, Chuangqi I.PARK, No....           Guangzhou
# 26  China Zhejiang Trading Center, Maoyang Village...             Wenling
# 27                                     1290 Ryan's Rd         Worthington
# 28                                      1080 Piper Ln          Burlington
# 29  ITC Vanke Center, 188 Quannan Road, Bincheng C...            Quanzhou
# 30                                  3275 Old Belle Rd           Spearfish
# 31                                  114 Bradford Blvd              Santee
# 32                                      6501 Grape Rd           Mishawaka
# 33                               3855 Indiana Rte 127              Angola
# 34                                    2157 Meeker Ave            Richmond
# 35                               4200 Sierra Vista Dr          Farmington
# 36                                 2631 Enterprise Rd            Goodland
# 37                                  1030 N Center Ave            Somerset
# 38                             214 South Highland Ave            Ossining
# 39                                 3939 Interstate 35          San Marcos
# 40                                      2535 Texas 71            Columbus
# 41                                   1305 W Havens St            Mitchell
# 42                                  3897 S Higuera St     San Luis Obispo
# 43                                   1000 Division St      East Greenwich
# 44                                     1391 Conant St              Maumee
# 45                                    11211 120th Ave    Pleasant Prairie
# 46                                    1308 Freedom Rd  Cranberry Township
# 47                                   2200 N Maple Ave          Rapid City
# 48                               5093 Fayetteville Rd           Lumberton
# 49                     Kanagawa, Totsuka Kamiyabe-cho            Yokohama
#
#              State      Country  Stalls     kW  Elev(m)  Open Date   Latitude  \
# 0               CA          USA      10  150.0      114 2013-07-13  34.614560
# 1               CA          USA       6  150.0       87 2013-10-18  39.926454
# 2               CA          USA      16  150.0      725 2012-11-19  34.849129
# 3               GA          USA       8  150.0       92 2014-07-10  31.448847
# 4               CA          USA       7  150.0       66 2014-04-29  38.771208
# 5               CA          USA      20  150.0       24 2014-09-24  34.238654
# 6               FL          USA      12  250.0        7 2022-11-19  29.223265
# 7               FL          USA      16  150.0        8 2013-07-25  27.313023
# 8               TX          USA      16  250.0      179 2021-11-17  32.867639
# 9   Chungcheongnam  South Korea       4  120.0       42 2019-12-20  36.909503
# 10        Lappland       Sweden       3  250.0      471 2021-12-16  68.407105
# 11              CA          USA      12  150.0       -8 2014-12-28  32.760837
# 12              IL          USA      10   72.0      194 2018-11-06  41.975091
# 13              CA          USA      46  250.0       -3 2014-09-26  33.741484
# 14              GA          USA       8  125.0        6 2014-01-15  32.135507
# 15              AZ          USA      12  250.0     1596 2014-01-15  34.922962
# 16              NC          USA      12  250.0      260 2021-11-19  35.587472
# 17       Guangdong        China      10  120.0       88 2014-07-26  22.618900
# 18              AZ          USA      12  250.0      338 2014-03-20  33.443011
# 19              CA          USA       8  125.0      262 2013-07-03  35.486560
# 20              AZ          USA      16  250.0      221 2014-05-17  32.943969
# 21              AZ          USA      12  250.0       43 2014-02-04  32.726686
# 22              CT          USA       4  150.0       82 2014-02-12  41.041538
# 23              CT          USA       2  120.0       19 2012-12-16  41.245814
# 24              FL          USA       6  150.0        7 2013-09-13  29.108566
# 25       Guangdong        China       6  250.0        0 2022-09-11  23.024584
# 26        Zhejiang        China       3  250.0        3 2022-09-22  28.398237
# 27              MN          USA       6  120.0      478 2013-12-11  43.633850
# 28              NC          USA       8  120.0      197 2013-10-16  36.070790
# 29          Fujian        China       3  250.0        3 2022-09-22  24.863103
# 30              SD          USA       6  150.0     1077 2017-10-30  44.520607
# 31              SC          USA       8  150.0       39 2013-12-27  33.485858
# 32              IN          USA       6  120.0      234 2013-12-11  41.717400
# 33              IN          USA       6  120.0      329 2013-12-09  41.699048
# 34              CA          USA      12  150.0        4 2019-09-16  37.919969
# 35              NM          USA       4  120.0     1673 2014-01-10  36.766371
# 36              KS          USA       6  150.0     1129 2014-06-13  39.326253
# 37              PA          USA       6  150.0      641 2014-01-10  40.017383
# 38              NY          USA      12  150.0       21 2019-06-14  41.144011
# 39              TX          USA      12  150.0      202 2013-08-17  29.827692
# 40              TX          USA       6  120.0       57 2013-10-07  29.690062
# 41              SD          USA       6  120.0      410 2013-12-18  43.701129
# 42              CA          USA      20  250.0       38 2021-11-19  35.247841
# 43              RI          USA       8  150.0       73 2014-01-06  41.660517
# 44              OH          USA       8  150.0      192 2014-01-13  41.578350
# 45              WI          USA       8  120.0      216 2014-02-13  42.518715
# 46              PA          USA       6  150.0      312 2014-04-04  40.683982
# 47              SD          USA       4  120.0     1006 2013-11-25  44.105601
# 48              NC          USA       8  150.0       40 2014-01-17  34.667629
# 49             NaN        Japan       4  120.0       43 2014-09-09  35.426015
#
#      Longitude
# 0  -120.188387
# 1  -122.198393
# 2  -117.085446
# 3   -83.532210
# 4  -121.266149
# 5  -119.177398
# 6   -81.099720
# 7   -80.406688
# 8   -96.767245
# 9   126.694075
# 10   18.676377
# 11 -115.532486
# 12  -87.866501
# 13 -116.215019
# 14  -81.212767
# 15 -110.145558
# 16  -80.873000
# 17  114.054820
# 18 -112.556876
# 19 -120.666330
# 20 -112.733506
# 21 -114.619093
# 22  -73.671661
# 23  -73.008988
# 24  -81.034569
# 25  113.339562
# 26  121.309214
# 27  -95.595647
# 28  -79.511211
# 29  118.679607
# 30 -103.890924
# 31  -80.475763
# 32  -86.188700
# 33  -85.000326
# 34 -122.348976
# 35 -108.144047
# 36 -101.725171
# 37  -79.077117
# 38  -73.861472
# 39  -97.979677
# 40  -96.537725
# 41  -98.044500
# 42 -120.671930
# 43  -71.497242
# 44  -83.664650
# 45  -87.950428
# 46  -80.108390
# 47 -103.212569
# 48  -79.002343
# 49  139.537549

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5876 entries, 0 to 5875
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Supercharger    5876 non-null   object
#  1   Street Address  5876 non-null   object
#  2   City            5876 non-null   object
#  3   State           5754 non-null   object
#  4   Country         5876 non-null   object
#  5   Stalls          5876 non-null   int64
#  6   kW              5870 non-null   float64
#  7   Elev(m)         5876 non-null   int64
#  8   Open Date       5126 non-null   datetime64[ns]
#  9   Latitude        5876 non-null   float64
#  10  Longitude       5876 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 505.1+ KB

# %%
raw_data.replace('???', pd.NA, inplace=True)
raw_data.replace('????', pd.NA, inplace=True)
# Step 2: Drop rows with any NaN values (which were previously '?')
df_cleaned = raw_data.dropna()

# Step 3: Reset index if needed
df_cleaned.reset_index(drop=True, inplace=True)

# %%
#dropping all rows with NaN values
cleaned_data= raw_data.dropna()
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5024 entries, 0 to 5125
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Supercharger    5024 non-null   object
#  1   Street Address  5024 non-null   object
#  2   City            5024 non-null   object
#  3   State           5024 non-null   object
#  4   Country         5024 non-null   object
#  5   Stalls          5024 non-null   int64
#  6   kW              5024 non-null   float64
#  7   Elev(m)         5024 non-null   int64
#  8   Open Date       5024 non-null   datetime64[ns]
#  9   Latitude        5024 non-null   float64
#  10  Longitude       5024 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 471.0+ KB

# %%
cleaned_data.head(50)
# Out:
#                                          Supercharger  \
# 0                                        Buellton, CA
# 1                                         Corning, CA
# 2                                         Barstow, CA
# 3                                          Tifton, GA
# 4                                       Roseville, CA
# 5                                          Oxnard, CA
# 6                Daytona Beach - Gateway North Dr, FL
# 7                                  Port St. Lucie, FL
# 8                                Dallas - Park Ln, TX
# 9                                Dangjin, South Korea
# 10                                 Björkliden, Sweden
# 11                                      El Centro, CA
# 12                                       Rosemont, IL
# 13                                          Indio, CA
# 14                                       Savannah, GA
# 15                                       Holbrook, AZ
# 16                                    Mooresville, NC
# 17             Shenzhen - Longhua Tesla Center, China
# 18                                        Buckeye, AZ
# 19                                     Atascadero, CA
# 20                                      Gila Bend, AZ
# 21                                           Yuma, AZ
# 22                         Greenwich - Northbound, CT
# 23                           Milford - Northbound, CT
# 24                                    Port Orange, FL
# 25  Guangzhou - Panyu Yingbin Road Tesla Center, C...
# 26             Wenling - Taizhou Tesla Service, China
# 27                                    Worthington, MN
# 28                                     Burlington, NC
# 29                    Quanzhou - Donghai Vanke, China
# 30                                      Spearfish, SD
# 31                                         Santee, SC
# 32                                      Mishawaka, IN
# 33                                         Angola, IN
# 34                                       Richmond, CA
# 35                                     Farmington, NM
# 36                                       Goodland, KS
# 37                                       Somerset, PA
# 38                                       Ossining, NY
# 39                                     San Marcos, TX
# 40                                       Columbus, TX
# 41                                       Mitchell, SD
# 42                   San Luis Obispo - Higuera St, CA
# 43                                 East Greenwich, RI
# 44                                         Maumee, OH
# 45                               Pleasant Prairie, WI
# 46                             Cranberry Township, PA
# 47                                     Rapid City, SD
# 48                                      Lumberton, NC
# 50                                         Gallup, NM
#
#                                        Street Address                City  \
# 0                                     555 McMurray Rd            Buellton
# 1                                          950 Hwy 99             Corning
# 2                                     2812 Lenwood Rd             Barstow
# 3                                        1310 U.S. 82              Tifton
# 4                                  1151 Galleria Blvd           Roseville
# 5                                   2751 Park View Ct              Oxnard
# 6                                   2330 Gateway N Dr       Daytona Beach
# 7                                1701 NW Peacock Blvd      Port St. Lucie
# 8                                        8080 Park Ln              Dallas
# 9   63, Songak-ro, Songak-eup, Dangjin-si, Chungch...             Dangjin
# 10                                 Björklidenvägen 70          Björkliden
# 11                                  3451 S Dogwood Rd           El Centro
# 12                           5220 Fashion Outlets Way            Rosemont
# 13                                   42100 Jackson St               Indio
# 14                                    400 Airways Ave            Savannah
# 15                                   2096 Navajo Blvd            Holbrook
# 16                               125 Center Square Dr         Mooresville
# 17  Longhua Auto City, No.1 Minkang Rd, Longhua Di...            Shenzhen
# 18                                    416 S Watson Rd             Buckeye
# 19                                6950 El Camino Real          Atascadero
# 20                                      826 W Pima St           Gila Bend
# 21                                  310 N Madison Ave                Yuma
# 22                                  3000 Merritt Pkwy           Greenwich
# 23                                    1 CT Turnpike N             Milford
# 24                             5302 S Williamson Blvd         Port Orange
# 25  Room 101-110, Building 1, Chuangqi I.PARK, No....           Guangzhou
# 26  China Zhejiang Trading Center, Maoyang Village...             Wenling
# 27                                     1290 Ryan's Rd         Worthington
# 28                                      1080 Piper Ln          Burlington
# 29  ITC Vanke Center, 188 Quannan Road, Bincheng C...            Quanzhou
# 30                                  3275 Old Belle Rd           Spearfish
# 31                                  114 Bradford Blvd              Santee
# 32                                      6501 Grape Rd           Mishawaka
# 33                               3855 Indiana Rte 127              Angola
# 34                                    2157 Meeker Ave            Richmond
# 35                               4200 Sierra Vista Dr          Farmington
# 36                                 2631 Enterprise Rd            Goodland
# 37                                  1030 N Center Ave            Somerset
# 38                             214 South Highland Ave            Ossining
# 39                                 3939 Interstate 35          San Marcos
# 40                                      2535 Texas 71            Columbus
# 41                                   1305 W Havens St            Mitchell
# 42                                  3897 S Higuera St     San Luis Obispo
# 43                                   1000 Division St      East Greenwich
# 44                                     1391 Conant St              Maumee
# 45                                    11211 120th Ave    Pleasant Prairie
# 46                                    1308 Freedom Rd  Cranberry Township
# 47                                   2200 N Maple Ave          Rapid City
# 48                               5093 Fayetteville Rd           Lumberton
# 50                                 111 Twin Buttes Rd              Gallup
#
#              State      Country  Stalls     kW  Elev(m)  Open Date   Latitude  \
# 0               CA          USA      10  150.0      114 2013-07-13  34.614560
# 1               CA          USA       6  150.0       87 2013-10-18  39.926454
# 2               CA          USA      16  150.0      725 2012-11-19  34.849129
# 3               GA          USA       8  150.0       92 2014-07-10  31.448847
# 4               CA          USA       7  150.0       66 2014-04-29  38.771208
# 5               CA          USA      20  150.0       24 2014-09-24  34.238654
# 6               FL          USA      12  250.0        7 2022-11-19  29.223265
# 7               FL          USA      16  150.0        8 2013-07-25  27.313023
# 8               TX          USA      16  250.0      179 2021-11-17  32.867639
# 9   Chungcheongnam  South Korea       4  120.0       42 2019-12-20  36.909503
# 10        Lappland       Sweden       3  250.0      471 2021-12-16  68.407105
# 11              CA          USA      12  150.0       -8 2014-12-28  32.760837
# 12              IL          USA      10   72.0      194 2018-11-06  41.975091
# 13              CA          USA      46  250.0       -3 2014-09-26  33.741484
# 14              GA          USA       8  125.0        6 2014-01-15  32.135507
# 15              AZ          USA      12  250.0     1596 2014-01-15  34.922962
# 16              NC          USA      12  250.0      260 2021-11-19  35.587472
# 17       Guangdong        China      10  120.0       88 2014-07-26  22.618900
# 18              AZ          USA      12  250.0      338 2014-03-20  33.443011
# 19              CA          USA       8  125.0      262 2013-07-03  35.486560
# 20              AZ          USA      16  250.0      221 2014-05-17  32.943969
# 21              AZ          USA      12  250.0       43 2014-02-04  32.726686
# 22              CT          USA       4  150.0       82 2014-02-12  41.041538
# 23              CT          USA       2  120.0       19 2012-12-16  41.245814
# 24              FL          USA       6  150.0        7 2013-09-13  29.108566
# 25       Guangdong        China       6  250.0        0 2022-09-11  23.024584
# 26        Zhejiang        China       3  250.0        3 2022-09-22  28.398237
# 27              MN          USA       6  120.0      478 2013-12-11  43.633850
# 28              NC          USA       8  120.0      197 2013-10-16  36.070790
# 29          Fujian        China       3  250.0        3 2022-09-22  24.863103
# 30              SD          USA       6  150.0     1077 2017-10-30  44.520607
# 31              SC          USA       8  150.0       39 2013-12-27  33.485858
# 32              IN          USA       6  120.0      234 2013-12-11  41.717400
# 33              IN          USA       6  120.0      329 2013-12-09  41.699048
# 34              CA          USA      12  150.0        4 2019-09-16  37.919969
# 35              NM          USA       4  120.0     1673 2014-01-10  36.766371
# 36              KS          USA       6  150.0     1129 2014-06-13  39.326253
# 37              PA          USA       6  150.0      641 2014-01-10  40.017383
# 38              NY          USA      12  150.0       21 2019-06-14  41.144011
# 39              TX          USA      12  150.0      202 2013-08-17  29.827692
# 40              TX          USA       6  120.0       57 2013-10-07  29.690062
# 41              SD          USA       6  120.0      410 2013-12-18  43.701129
# 42              CA          USA      20  250.0       38 2021-11-19  35.247841
# 43              RI          USA       8  150.0       73 2014-01-06  41.660517
# 44              OH          USA       8  150.0      192 2014-01-13  41.578350
# 45              WI          USA       8  120.0      216 2014-02-13  42.518715
# 46              PA          USA       6  150.0      312 2014-04-04  40.683982
# 47              SD          USA       4  120.0     1006 2013-11-25  44.105601
# 48              NC          USA       8  150.0       40 2014-01-17  34.667629
# 50              NM          USA       8  250.0     1970 2014-01-07  35.505278
#
#      Longitude
# 0  -120.188387
# 1  -122.198393
# 2  -117.085446
# 3   -83.532210
# 4  -121.266149
# 5  -119.177398
# 6   -81.099720
# 7   -80.406688
# 8   -96.767245
# 9   126.694075
# 10   18.676377
# 11 -115.532486
# 12  -87.866501
# 13 -116.215019
# 14  -81.212767
# 15 -110.145558
# 16  -80.873000
# 17  114.054820
# 18 -112.556876
# 19 -120.666330
# 20 -112.733506
# 21 -114.619093
# 22  -73.671661
# 23  -73.008988
# 24  -81.034569
# 25  113.339562
# 26  121.309214
# 27  -95.595647
# 28  -79.511211
# 29  118.679607
# 30 -103.890924
# 31  -80.475763
# 32  -86.188700
# 33  -85.000326
# 34 -122.348976
# 35 -108.144047
# 36 -101.725171
# 37  -79.077117
# 38  -73.861472
# 39  -97.979677
# 40  -96.537725
# 41  -98.044500
# 42 -120.671930
# 43  -71.497242
# 44  -83.664650
# 45  -87.950428
# 46  -80.108390
# 47 -103.212569
# 48  -79.002343
# 50 -108.828094

# %%
cleaned_data.describe()
# Out:
#             Stalls           kW      Elev(m)                      Open Date  \
# count  5024.000000  5024.000000  5024.000000                           5024
# mean      9.166401   203.293790   229.578424  2020-07-06 19:22:50.063694080
# min       2.000000    72.000000   -11.000000            2012-11-19 00:00:00
# 25%       6.000000   150.000000    13.000000            2018-10-10 12:00:00
# 50%       8.000000   250.000000    67.000000            2021-03-26 00:00:00
# 75%      12.000000   250.000000   249.000000            2022-09-22 00:00:00
# max      80.000000   250.000000  4338.000000            2023-06-03 00:00:00
# std       5.844574    59.422833   423.489031                            NaN
#
#           Latitude    Longitude
# count  5024.000000  5024.000000
# mean     37.026281    11.118498
# min     -44.354408  -157.941632
# 25%      30.701251   -82.490553
# 50%      37.462941     8.552476
# 75%      43.618687   114.726761
# max      70.999582   174.840171
# std      12.517054    96.147825

# %%
engine = create_engine("sqlite:///Tesla.sqlite")

# %%
cleaned_data = cleaned_data.rename(columns= {"Street Address" : "Street_Address","Elev(m)":"Elev_m","Open Date":"Open_Date"})

# %%
cleaned_data.to_csv("cleaned_data.csv", index=False)

# %%
query = """CREATE TABLE supercharge_locations (
    id INTEGER PRIMARY KEY,
    Supercharger TEXT,
    Street_Address TEXT,
    City TEXT,
    State TEXT,
    Country TEXT,
    Stalls INTEGER,
    kW REAL,
    Elev_m INTEGER,
    Open_Date DATE,
    Latitude REAL,
    Longitude REAL
)"""

with engine.connect() as con:
    con.execute(text(query))

# %%
cleaned_data.columns
# Out:
# Index(['Supercharger', 'Street_Address', 'City', 'State', 'Country', 'Stalls',
#        'kW', 'Elev_m', 'Open_Date', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
cleaned_data.to_sql("supercharge_locations", con=engine, index=False, method="multi", if_exists="append")
# Out:
# 5024

# %%
# INSPECT to confirm existence

# Create the inspector and connect it to the engine
inspector_gadget = inspect(engine)

# Collect the names of tables within the database
tables = inspector_gadget.get_table_names()

# print metadata for each table
for table in tables:
    print(table)
    print("-----------")
    
    # get columns
    columns = inspector_gadget.get_columns(table)
    for column in columns:
        print(column["name"], column["type"])

    print()
# Out:
# supercharge_locations
# -----------
# id INTEGER
# Supercharger TEXT
# Street_Address TEXT
# City TEXT
# State TEXT
# Country TEXT
# Stalls INTEGER
# kW REAL
# Elev_m INTEGER
# Open_Date DATE
# Latitude REAL
# Longitude REAL

# %%
engine.dispose()
